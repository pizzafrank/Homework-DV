# %% [markdown]
# ### Week7 Participation 2

# %%
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ##### Listing 2-2. Importing and Using the Matplotlib Library

# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
X = [590,540,740,130,810,300,320,230,470,620,770,250]
Y = [32,36,39,52,61,72,77,75,68,57,48,48]
plt.scatter(X,Y)
plt.xlim(0,1000)
plt.ylim(0,100)
#scatter plot color
plt.scatter(X, Y, s=300, c='red', marker='+')
#change axes ranges
plt.xlim(0,1000)
plt.ylim(0,100)
#add title
plt.title('Relationship Between Temperature and Iced Coffee Sales')
#add x and y labels
plt.xlabel('Sold Coffee')
plt.ylabel('Temperature in Fahrenheit')
#show plot
plt.show()

# %% [markdown]
# #### Listing 2-3. Importing Numpy and Calling Its Functions

# %%
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
# Create empty figure
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
# set the x and y axis range
plt.xlim(0, 11)
plt.ylim(-2, 2)
plt.axis('tight')
#add title
plt.title('Plotting data using sin and cos')
# Out:
# Text(0.5, 1.0, 'Plotting data using sin and cos')

# %% [markdown]
# #### Listing 2-4. Importing and Using the Seaborn Library

# %% [markdown]
# ###### Seaborn graph

# %%
# %matplotlib inline
plt.style.use('classic')
plt.style.use('seaborn-whitegrid')
# Create some data
data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]],
size=2000)
data = pd.DataFrame(data, columns=['x', 'y'])
# Plot the data with seaborn
sns.distplot(data['x'])
sns.distplot(data['y'])

# %%
for col in 'xy':
    sns.kdeplot(data[col], shade=True)

# %% [markdown]
# ###### Two-dimensional kernel density graph

# %%
sns.kdeplot(data)
# Out:
# /Users/frankyang/opt/anaconda3/lib/python3.7/site-packages/seaborn/distributions.py:679: UserWarning:
#
# Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.

# %% [markdown]
# ###### Joint distribution graph

# %%
sns.jointplot("x", "y", data, kind='kde')

# %% [markdown]
# ###### A hexagonally based histogram graph

# %%
sns.jointplot("x", "y", data, kind='hex')

# %% [markdown]
# ###### Multidimensional relationships graph

# %%
sns.pairplot(data)

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in ./opt/anaconda3/lib/python3.7/site-packages (4.5.4)
# Requirement already satisfied: retrying>=1.3.3 in ./opt/anaconda3/lib/python3.7/site-packages (from plotly) (1.3.3)
# Requirement already satisfied: six in ./opt/anaconda3/lib/python3.7/site-packages (from plotly) (1.12.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Listing 2-5. Importing and Using the Plotly Library

# %% [markdown]
# ###### Dynamic heatmap graph

# %%
import plotly.graph_objs as go
x = np.random.randn(2000)
y = np.random.randn(2000)
iplot([go.Histogram2dContour(x=x, y=y,
contours=dict (coloring='heatmap')),
go.Scatter(x=x, y=y, mode='markers',
marker=dict(color='White', size=3,
opacity=0.3))], show_link=False)
# Out:
# <div>
#
#
#             <div id="727a0e8c-ea55-4870-9da9-c206a2c77de7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById
.1693294696649434, -0.8015172942645269, 1.8782041840193224, 0.5372488596678946, 0.44575135659865855, -0.10482550787056158, 1.2622426485735314, 0.5740191197875982, -1.4106483622319028, 0.10227913234609826, 0.13391814337804328, 0.049158751813585665, -0.5535777564669971, -0.08964809925113422, -1.1127516172708847, 0.24150484761042326, 1.0686066261729545, -0.3716468341096874, -0.48096405325937347, -0.2628065796160439, -1.3224296664727957, -0.4535676177227837, 0.6646154401445518, -0.5191134228931186, 0.7810312612942127, -0.06510132336962296, -0.6629453172714614, 0.9897738805518083, 1.2362273530473036, -1.4512309887031318, -0.43614471129659144, -0.23911593120023958, 0.04077875905366245, -0.8753937493294061, -0.8833392202510036, 0.3708415442938532, 0.6946144224835413, -1.2758093274530455, 2.266506054014991, 2.498436773069957, 0.9242877836378228, -1.11995389489079, 0.699099483915702, -1.6697829363605738, -0.06817865611724334, -1.0922758483279114, 0.7737752206247368, -2.3738439221154706, -0.6823522131847192, 0.5765569328248862, 0.04172417946989826, -2.23046540349339, -0.16288154753486833, 0.7128232213014672, -1.6732601129890414, 0.5402087082154592, -0.7567664059841085, -0.5757285044786561, 2.248294095872619, 0.3882512758205325, -0.300888503403042, 0.6178378851331751, 1.4138958220796711, -2.186746905123237, 0.10033471015079314, -0.37481878168288846, 0.15357978897889135, -1.4278801956297025, 0.045367630309818406, 1.1303770379505698, 0.35010691 ...

# %% [markdown]
# ###### Offline Plotly graph

# %%
import plotly.offline as offline
offline.plot({'data': [{'y': [14, 22, 30,
44]}],'layout': {'title': 'Offline Plotly', 'font':
dict(size=16)}}, image='png')
# Out:
# 'temp-plot.html'

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs
from plotly.offline import init_notebook_mode
from plotly.offline import plot
import plotly.offline as py
from plotly.offline import iplot
from plotly.graph_objs import Scatter
py.init_notebook_mode(connected=True)
print (__version__)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 4.5.4

# %% [markdown]
# ###### Plotly dynamic graph

# %%
import plotly.graph_objs as go
plot([go.Scatter(x=[95, 77, 84], y=[75, 67, 56])])
# Out:
# 'temp-plot.html'

# %% [markdown]
# #### Listing 2-7. Running Basic Plotting

# %%
df = pd.DataFrame(np.random.randn(200,6),index= pd.date_range('1/9/2009', periods=200), columns= list('ABCDEF'))
df.plot(figsize=(20, 10)).legend(bbox_to_anchor=(1, 1))

# %% [markdown]
# #### Listing 2-8. Direct Plotting

# %%
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May'])
df.plot.bar(figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %% [markdown]
# #### Listing 2-9. Create a stacked bar plot

# %%
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May']) 
df.plot.bar(stacked=True,
figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %% [markdown]
# #### Listing 2-10. Bar Plots

# %%
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May']) 
df.plot.barh(stacked=True,figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))

# %% [markdown]
# #### Listing 2-11. Using the Bar’s bins Attribute

# %%
df = pd.DataFrame(np.random.rand(20,5), columns=['Jan','Feb','March','April', 'May'])
df.plot.hist(bins= 20, figsize=(10,8)).legend(bbox_to_anchor=(1.2, 1))

# %% [markdown]
# #### Listing 2-12. Multiple Histograms per Column

# %%
df=pd.DataFrame({'April':np.random.randn(1000)+1,'May':np.random.randn(1000),'June': np.random.randn(1000) - 1}, columns=['April','May', 'June'])
df.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a234b84d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a245df5d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a2776ddd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a27cc8410>]],
#       dtype=object)

# %% [markdown]
# #### Listing 2-13. Creating a Box Plot

# %%
df = pd.DataFrame(np.random.rand(20,5),columns=['Jan','Feb','March','April', 'May'])
df.plot.box()

# %% [markdown]
# #### Listing 2-14. Creating an Area Plot

# %%
df = pd.DataFrame(np.random.rand(20,5),columns= ['Jan','Feb','March','April', 'May'])
df.plot.area(figsize=(6, 4)).legend(bbox_to_anchor=(1.3, 1))

# %% [markdown]
# #### Listing 2-15. Creating a Scatter Plot

# %%
df = pd.DataFrame(np.random.rand(20,5),columns= ['Jan','Feb','March','April', 'May'])
df.plot.scatter(x='Feb', y='Jan', title='Temperature over two months ')

# %% [markdown]
# #### Exercise 5. Write a Python script to create a data frame for the following table:

# %%
salesMen = ['Ahmed', 'Omar', 'Ali', 'Ziad', 'Salwa', 'Lila']
Mobile_Sales = [2540, 1370, 1320, 2000, 2100, 2150]
TV_Sales = [2200, 1900, 2150, 1850, 1770, 2000]
df = pd.DataFrame()
df ['Name'] =salesMen
df ['Mobile_Sales'] = Mobile_Sales
df['TV_Sales']=TV_Sales
df.set_index("Name",drop=True,inplace=True)
df
# Out:
#        Mobile_Sales  TV_Sales
# Name
# Ahmed          2540      2200
# Omar           1370      1900
# Ali            1320      2150
# Ziad           2000      1850
# Salwa          2100      1770
# Lila           2150      2000

# %%
df.plot.bar(figsize=(20, 10), rot=0).legend(bbox_to_anchor=(1.1, 1))
plt.xlabel('Salesmen')
plt.ylabel('Sales')
plt.title('Sales Volume for two salesmen in \nJanuary and April 2017')
plt.show()

# %%
df.plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a25e0d190>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a25e839d0>],
#       dtype=object)

# %%
df.plot.box()

# %%
df.plot.area(figsize=(6, 4)).legend(bbox_to_anchor=(1.3,1))

# %%
df.plot.bar(stacked=True, figsize=(20, 10)).legend(bbox_to_anchor=(1.1, 1))
